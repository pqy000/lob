# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize=(8, 6))

# plt.subplot(111)
num = 2
x = [2,3,4,5,6,7,8,9,10]#点的横坐标
k1   =  [22.33,24.28,42.32,48.31,51.3,49.4,48.3,47.32,46.22]
k3   = [16.42,20.33,24.58,30.32,39.31,36.21,38.32,37.3,37.6]

# %%
plt.plot(x,k1,'s-',color = 'blue',label="1-month")
plt.plot(x,k3,'h-',color = 'red', lw=2, label="2-month")
plt.xlabel("Month", fontdict={'family' : 'Times New Roman', 'size': 23})#横坐标名字
plt.ylabel("Accuracy", fontdict={'family' : 'Times New Roman', 'size': 24})#纵坐标名字
plt.xticks(fontsize=25,fontproperties = 'Times New Roman' )
plt.yticks(fontsize=25,fontproperties = 'Times New Roman' )
# plt.legend(loc = "best")#图例
# plt.title("Air-quality")
# plt.ylim(3, 18)
plt.legend(loc = "best", prop={'family' : 'Times New Roman', 'size': 19.5})
plt.grid()
fig.tight_layout()
ax1=plt.gca()
ax1.spines['top'].set_linewidth('1.3')
ax1.spines['bottom'].set_linewidth('1.3')
ax1.spines['left'].set_linewidth('1.3')
ax1.spines['right'].set_linewidth('1.3')
plt.savefig("Accuracy1.pdf")
plt.show()

# %%
num = 2
x = [2,3,4,5,6,7,8,9,10]#点的横坐标
k1   =  [1.6482,1.8446,1.928,2.0631,2.1321,2.2732,2.25,2.19,2.18]
k3   = [0.8284,1.482,1.7646,1.83,2.0126,1.9921,1.932,1.95,1.94]

# %%
plt.plot(x,k1,'s-',color = 'blue',label="1-month")
plt.plot(x,k3,'h-',color = 'red', lw=2, label="2-month")
plt.xlabel("Month", fontdict={'family' : 'Times New Roman', 'size': 23})#横坐标名字
plt.ylabel("S-Value", fontdict={'family' : 'Times New Roman', 'size': 24})#纵坐标名字
plt.xticks(fontsize=25,fontproperties = 'Times New Roman' )
plt.yticks(fontsize=25,fontproperties = 'Times New Roman' )
# plt.legend(loc = "best")#图例
# plt.title("Air-quality")
# plt.ylim(3, 18)
plt.legend(loc = "best", prop={'family' : 'Times New Roman', 'size': 19.5})
plt.grid()
fig.tight_layout()
ax1=plt.gca()
ax1.spines['top'].set_linewidth('1.3')
ax1.spines['bottom'].set_linewidth('1.3')
ax1.spines['left'].set_linewidth('1.3')
ax1.spines['right'].set_linewidth('1.3')
plt.savefig("Accuracy1.pdf")
plt.show()

# %%
# Todo:

#每个月重新训练（稳定有效?）

#-2021年1-12月 -> 预测未来1个月 (S-value和Accuracy曲线) online
## 每分钟预测(label/仓位)
#-2021年6-12月 -> 2022年1-12月 (S-value和Accuracy曲线) 权重不更新
#-2021年6-12月 -> 2022年1-12月 (S-value和Accuracy曲线) 权重不更新

# %%
# Todo:
## 每分钟预测(label/仓位)
# GPU同样实验设置 
## window_size可能会减小?
# 眼轴的图像识别
